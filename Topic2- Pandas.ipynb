# %% [markdown]
# ### Pandas
#
# - Pandas being one of the most popular package in Python is widely used for data manipulation. It is a very powerful and versatile package which makes data cleaning and wrangling much easier and pleasant.
#
# - The Pandas library has a great contribution to the python community and it makes python as one of the top programming language for data science and analytics. It has become first choice of data analysts and scientists for data analysis and manipulation.
#
# ### What is pandas package?
#
# Pandas package has many functions which are the essence for data handling and manipulation. In short, it can perform the following tasks for you -
#
# - Create a structured data set similar to R's data frame and Excel spreadsheet.
# - Reading data from various sources such as CSV, TXT, XLSX, SQL database, R etc.
# - Selecting particular rows or columns from data set
# - Arranging data in ascending or descending order
# - Filtering data based on some conditions
# - Summarizing data by classification variable
# - Reshape data into wide or long format
# - Time series analysis
# - Merging and concatenating two datasets
# - Iterate over the rows of dataset
# - Writing or Exporting data in CSV or Excel format
#
# ### Important pandas functions to remember
#
# The following is a list of common tasks along with pandas functions:

# %% [markdown]
# ### What Are Pandas Data Frames?
#
# Those who are familiar with R know the data frame as a way to store data in rectangular grids that can easily be overviewed. Each row of these grids corresponds to measurements or values of an instance, while each column is a vector containing data for a specific variable. This means that a data frame’s rows do not need to contain, but can contain, the same type of values: they can be numeric, character, logical, etc.
#
# Now, DataFrames in Python are very similar: they come with the Pandas library, and they are defined as two-dimensional labeled data structures with columns of potentially different types.
#
# ##### In general, you could say that the Pandas DataFrame consists of three main components: the data, the index, and the columns.
#
# Firstly, the DataFrame can contain data that is:
#
# - a Pandas DataFrame
# - a Pandas Series: a one-dimensional labeled array capable of holding any data type with axis labels or index. An example of a Series object is one column from a DataFrame.
# - a NumPy ndarray, which can be a record or structured
# - a two-dimensional ndarray
# - dictionaries of one-dimensional ndarray’s, lists, dictionaries or Series.

# %% [markdown]
# ### Pandas Series Object
#
# ![series+series-dataframe.png](attachment:series+series-dataframe.png)

# %% [markdown]
# ### Pandas Dataframe Object
#
# ![7205.1610253721.jpg](attachment:7205.1610253721.jpg)

# %% [markdown]
# ### 1. How To Create a Pandas DataFrame

# %%
# Create a single column dataframe
import pandas as pd

countries = ['India', 'China', 'United States', 'Pakistan', 'Indonesia']

df1= pd.DataFrame(data= countries)
print(df1)
print()
print(type(df1))
# Out:
#                0
# 0          India
# 1          China
# 2  United States
# 3       Pakistan
# 4      Indonesia
#
# <class 'pandas.core.frame.DataFrame'>

# %%
country= pd.Series(['India', 'China', 'United States', 'Pakistan', 'Indonesia'])
language=pd.Series(['hindi','chinese','english','urdu','english'])
indices= ['India', 'China', 'United States', 'Pakistan', 'Indonesia']
df_ser= pd.DataFrame(zip(country,language), 
                     columns=['Country','Language'],
                    index=indices
                    )
df_ser
# Out:
#                      Country Language
# India                  India    hindi
# China                  China  chinese
# United States  United States  english
# Pakistan            Pakistan     urdu
# Indonesia          Indonesia  english

# %%
# Create a dictionary where the keys are the feature names and the values are a list of the feature values

country_info= {
'Country': ['India', 'China', 'United States', 'Pakistan', 'Indonesia'],
'Population' : [1393409038, 1444216107, 332129157, 225199937, 276361783],
'Currency' : ['Indian Rupee', 'Renminbi', 'US Dollar', 'Pakistani Rupee', 'Indonesian Rupiah']
}

df_dict= pd.DataFrame(data= country_info)
df_dict
# Out:
#          Country  Population           Currency
# 0          India  1393409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361783  Indonesian Rupiah

# %%
# Create a list of lists where each inner list is a row of the DataFrame
data_list = [['India', 1393409038, 'Indian Rupee'],
             ['China', 1444216107, 'Renminbi'],
             ['United States', 332129157, 'US Dollar'],
             ['Pakistan', 225199937, 'Pakistani Rupee'],
             ['Indonesia', 276361783, 'Indonesian Rupiah']]

df_lists= pd.DataFrame(data= data_list, columns=['Country','Population','Currency'])
df_lists
# Out:
#          Country  Population           Currency
# 0          India  1393409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361783  Indonesian Rupiah

# %%
# Create a list of dictionaries where the keys are the column names and the values are a particular feature value.
list_of_dicts = [{'Country': 'India', 'Population': 139409038, 'Currency': 'Indian Rupee'},
                 {'Country': 'China', 'Population': 1444216107,
                     'Currency': 'Renminbi'},
                 {'Country': 'United States', 'Population': 332129157,
                     'Currency': 'US Dollar'},
                 {'Country': 'Pakistan', 'Population': 225199937,
                     'Currency': 'Pakistani Rupee'},
                 {'Country': 'Indonesia', 'Population': 276361763, 'Currency': 'Indonesian Rupiah'}, ]

df_list_dicts= pd.DataFrame(data= list_of_dicts)
df_list_dicts
# Out:
#          Country  Population           Currency
# 0          India   139409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361763  Indonesian Rupiah

# %%
import numpy as np

# Create a numpy array where each inner array is a row of the DataFrame

array2d= np.array([['India', 1393409038, 'Indian Rupee'],
                         ['China', 1444216107, 'Renminbi'],
                         ['United States', 332129157, 'US Dollar'],
                         ['Pakistan', 225199937, 'Pakistani Rupee'],
                         ['Indonesia', 276361783, 'Indonesian Rupiah']])
df_array= pd.DataFrame(data=array2d, 
                       columns=['one','two','three'])
df_array
# Out:
#              one         two              three
# 0          India  1393409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361783  Indonesian Rupiah

# %%
# Making a new DataFrame from existing DataFrames
# 2 dataframes

#Combining- Horizontally, Vertically

countries = ['India', 'China', 'United States', 'Pakistan', 'Indonesia']
one= pd.DataFrame(countries, columns=['Country'])
one
# Out:
#          Country
# 0          India
# 1          China
# 2  United States
# 3       Pakistan
# 4      Indonesia

# %%
df2_data = {'Population': [1393409038, 1444216107, 332129157, 225199937, 276361783],
            'Currency': ['Indian Rupee', 'Renminbi', 'US Dollar', 'Pakistani Rupee', 'Indonesian Rupiah']}

two= pd.DataFrame(data= df2_data)
two
# Out:
#    Population           Currency
# 0  1393409038       Indian Rupee
# 1  1444216107           Renminbi
# 2   332129157          US Dollar
# 3   225199937    Pakistani Rupee
# 4   276361783  Indonesian Rupiah

# %%
# Horizonatally(Merge)
combined_horiz= pd.concat([one, two], axis='columns')
combined_horiz
# Out:
#          Country  Population           Currency
# 0          India  1393409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361783  Indonesian Rupiah

# %%
one
# Out:
#          Country
# 0          India
# 1          China
# 2  United States
# 3       Pakistan
# 4      Indonesia

# %%
df_top_data = {'Country': ['India', 'China', 'United States'],
               'Population': [1393409038, 1444216107, 332129157],
               'Currency': ['Indian Rupee', 'Renminbi', 'US Dollar']}
df_1= pd.DataFrame(data= df_top_data)
df_1
# Out:
#          Country  Population      Currency
# 0          India  1393409038  Indian Rupee
# 1          China  1444216107      Renminbi
# 2  United States   332129157     US Dollar

# %%
df_bottom_data = {'Country': ['Pakistan', 'Indonesia'], 'Population': [
    225199937, 276361783], 'Currency': ['Pakistani Rupee', 'Indonesian Rupiah']}
df_2= pd.DataFrame(data= df_bottom_data)
df_2
# Out:
#      Country  Population           Currency
# 0   Pakistan   225199937    Pakistani Rupee
# 1  Indonesia   276361783  Indonesian Rupiah

# %%
# Combining Vertically- Appending

combined_rows= pd.concat([df_1,df_2], ignore_index=True)
combined_rows
# Out:
#          Country  Population           Currency
# 0          India  1393409038       Indian Rupee
# 1          China  1444216107           Renminbi
# 2  United States   332129157          US Dollar
# 3       Pakistan   225199937    Pakistani Rupee
# 4      Indonesia   276361783  Indonesian Rupiah

# %%
# Making pandas DataFrames from text files

one_txt= pd.read_table('one.txt', sep=',')
one_txt
# Out:
#    N1  N2  N3
# 0   1   2   3
# 1   4   5   6
# 2   7   8   9

# %%
one_csv= pd.read_csv('one1.csv', sep=';')
one_csv
# Out:
#    N1  N2  N3
# 0   1   2   3
# 1   4   5   6
# 2   7   8   9

# %%
# Creating a CSV file

import pandas as pd

dt = {'ID': [11, 12, 13, 14, 15],
            'first_name': ['David', 'Jamie', 'Steve', 'Stevart', 'John'],
            'company': ['Aon', 'TCS', 'Google', 'RBS', '.'],
            'salary': [74, 76, 96, 71, 78]}

columns = ['ID', 'first_name', 'company', 'salary']

df= pd.DataFrame(data=dt, columns=columns)
df.to_csv('country_data.csv', index=False)

# %%
# 1 : Read CSV file with header row

df_csv= pd.read_csv('country_data.csv')
df_csv
# Out:
#    ID first_name company  salary
# 0  11      David     Aon      74
# 1  12      Jamie     TCS      76
# 2  13      Steve  Google      96
# 3  14    Stevart     RBS      71
# 4  15       John       .      78

# %%
# 2 : Read CSV file with no header

df_csv= pd.read_csv('country_data.csv', header=None)
# df_csv

df_csv= pd.read_csv('country_data.csv', header=None, prefix='Var')
df_csv
# Out:
# C:\Users\Administrator.LAB-STUDENT\AppData\Local\Temp\ipykernel_1808\2800722780.py:6: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df_csv= pd.read_csv('country_data.csv', header=None, prefix='Var')
#    Var0     Var1    Var2  Var3
# 0    11    David     Aon    74
# 1    12    Jamie     TCS    76
# 2    13    Steve  Google    96
# 3    14  Stevart     RBS    71
# 4    15     John       .    78

# %%
# 2A Define your own column names instead of header row from CSV file

df_csv= pd.read_csv('country_data.csv', 
                    header=None, 
                    names=['ID','first_name','company','salary'])
df_csv
# Out:
#    ID first_name company  salary
# 0  11      David     Aon      74
# 1  12      Jamie     TCS      76
# 2  13      Steve  Google      96
# 3  14    Stevart     RBS      71
# 4  15       John       .      78

# %%
# 3 : Skip rows but keep header

df_csv= pd.read_csv('country_data.csv', header=3)
df_csv
# Out:
#    ID first_name company  salary
# 0  11      David     Aon      74
# 1  12      Jamie     TCS      76
# 2  13      Steve  Google      96
# 3  14    Stevart     RBS      71
# 4  15       John       .      78

# %%
# 5 : Specify missing values

df_csv= pd.read_csv('country_data.csv', header=0, na_values='NA')
df_csv
# Out:
#    ID first_name company  salary
# 0  11      David     Aon      74
# 1  12      Jamie     TCS      76
# 2  13      Steve  Google      96
# 3  14    Stevart     RBS      71
# 4  15       John     NaN      78

# %%
df_csv.isna().sum()
# Out:
# ID            0
# first_name    0
# company       1
# salary        0
# dtype: int64

# %%
# 6 : Set Index Column

df_csv= pd.read_csv('country_data.csv', header=0, na_values='NA', index_col='ID')
df_csv
# Out:
#    first_name company  salary
# ID
# 11      David     Aon      74
# 12      Jamie     TCS      76
# 13      Steve  Google      96
# 14    Stevart     RBS      71
# 15       John     NaN      78

# %%
# 7 : Read CSV File from External URL- "http://winterolympicsmedals.com/medals.csv"

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv')
medals
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
# 8 : Skip Last 5 Rows While Importing CSV

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', skipfooter=5)
medals
# Out:
# C:\Users\Administrator.LAB-STUDENT\AppData\Local\Temp\ipykernel_1808\2774504592.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', skipfooter=5)
#       Year      City       Sport      Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT             individual
# 1     1924  Chamonix     Skating  Figure skating  AUT             individual
# 2     1924  Chamonix     Skating  Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN             ice hockey
# ...    ...       ...         ...             ...  ...                    ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA        Alpine combined
# ...

# %%
#Alternate
medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv')
medals.head(n=-5)
# Out:
#       Year      City       Sport      Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT             individual
# 1     1924  Chamonix     Skating  Figure skating  AUT             individual
# 2     1924  Chamonix     Skating  Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN             ice hockey
# ...    ...       ...         ...             ...  ...                    ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA        Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA           giant slalom
# 2303  2006     Turin      Skiing  Freestyle Ski.  USA                 moguls
# 2304  2006     Turin      Skiing       Snowboard  USA  Giant parallel slalom
# 2305  2006     Turin      Skiing       Snowboard  USA              Half-pipe
#
#      Event gender   Medal
# ...

# %%
# 9 : Read only first 5 rows

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', nrows=5)
medals

#Alternate
medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', nrows=5)
medals.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
# 10 : Interpreting "," as thousands separator

one= pd.read_table('one12.txt', sep=' ', thousands=',')
one
# Out:
#      Country  Population           Currency
# 0   Pakistan   225199937    Pakistani_Rupee
# 1  Indonesia   276361783  Indonesian_Rupiah

# %%
# 11 : Read only specific columns

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', 
                   usecols=['Year','NOC'])
medals
# Out:
#       Year  NOC
# 0     1924  AUT
# 1     1924  AUT
# 2     1924  AUT
# 3     1924  BEL
# 4     1924  CAN
# ...    ...  ...
# 2306  2006  USA
# 2307  2006  USA
# 2308  2006  USA
# 2309  2006  USA
# 2310  2006  USA
#
# [2311 rows x 2 columns]

# %%
medals[['Year','NOC']]
# Out:
#       Year  NOC
# 0     1924  AUT
# 1     1924  AUT
# 2     1924  AUT
# 3     1924  BEL
# 4     1924  CAN
# ...    ...  ...
# 2306  2006  USA
# 2307  2006  USA
# 2308  2006  USA
# 2309  2006  USA
# 2310  2006  USA
#
# [2311 rows x 2 columns]

# %%
# 12 : Read some rows and columns

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', 
                   usecols=['Year','NOC'], nrows=15)
medals
# Out:
#     Year  NOC
# 0   1924  AUT
# 1   1924  AUT
# 2   1924  AUT
# 3   1924  BEL
# 4   1924  CAN
# 5   1924  FIN
# 6   1924  FIN
# 7   1924  FIN
# 8   1924  FIN
# 9   1924  FIN
# 10  1924  FIN
# 11  1924  FIN
# 12  1924  FIN
# 13  1924  FIN
# 14  1924  FIN

# %%
medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', 
                   usecols=['Year','NOC'])
medals.sample(15)
# Out:
#       Year  NOC
# 1476  1994  GBR
# 1332  1992  FRA
# 1986  2002  NOR
# 470   1960  USA
# 1113  1984  URS
# 2266  2006  SUI
# 1928  2002  GER
# 2251  2006  RUS
# 2243  2006  RUS
# 1799  1998  RUS
# 2260  2006  SUI
# 887   1976  USA
# 1231  1988  URS
# 1296  1992  CHN
# 747   1972  SUI

# %%
# 13 : Read file with semi colon delimiter

one1_csv=  pd.read_csv('one1.csv', sep=';')
one1_csv
# Out:
#      Country  Population           Currency
# 0   Pakistan   225199937    Pakistani Rupee
# 1  Indonesia   276361783  Indonesian Rupiah

# %%
# 14 : Change column type while importing CSV

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', 
                    dtype={'Year':'float'})
medals
# Out:
#         Year      City       Sport      Discipline  NOC            Event  \
# 0     1924.0  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924.0  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924.0  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924.0  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924.0  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...      ...       ...         ...             ...  ...              ...
# 2306  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006.0     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006.0     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
# 15 : Measure time taken to import big CSV file

medals= pd.read_csv('http://winterolympicsmedals.com/medals.csv', 
                    dtype={'Year':'float'}, verbose=True)
medals
# Out:
# Tokenization took: 1.00 ms
# Type conversion took: 2.00 ms
# Parser memory cleanup took: 0.00 ms
#         Year      City       Sport      Discipline  NOC            Event  \
# 0     1924.0  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924.0  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924.0  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924.0  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924.0  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...      ...       ...         ...             ...  ...              ...
# 2306  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006.0     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006.0     Turin      Skiing       Snowboard  USA  Snowboard Cross
# ...

# %%
# Reading Excel file with defualt sheet(sheet#1)

import pandas as pd

df_xl= pd.read_excel('superstore.xls')
df_xl
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Reading Excel file with a specific sheet

import pandas as pd

# df_xl_returns= pd.read_excel('superstore.xls', sheet_name='Returns')
# df_xl_returns

#Altenate sol

df_xl_returns= pd.read_excel('superstore.xls', sheet_name=2)
df_xl_returns
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
# Reading Excel file with many sheets

import pandas as pd

df_xl_returns= pd.read_excel('superstore.xls', sheet_name=[1,2])
df_xl_returns
# Out:
# {1:     Returned        Order ID
#  0        Yes  CA-2017-153822
#  1        Yes  CA-2017-129707
#  2        Yes  CA-2014-152345
#  3        Yes  CA-2015-156440
#  4        Yes  US-2017-155999
#  ..       ...             ...
#  291      Yes  CA-2015-101910
#  292      Yes  CA-2017-156958
#  293      Yes  CA-2016-105585
#  294      Yes  CA-2016-148796
#  295      Yes  CA-2015-149636
#
#  [296 rows x 2 columns],
#  2:               Person   Region
#  0      Anna Andreadi     West
#  1        Chuck Magee     East
#  2     Kelly Williams  Central
#  3  Cassandra Brandow    South}

# %%
#Reading MySQL Database files in pandas dataframe

import mysql.connector

connect_db= mysql.connector.connect( host= 'localhost',
                                    user= 'root',
                                    password= '123@MySQL',
                                    database= 'sam_DB'
)

my_cursor= connect_db.cursor()
# my_cursor.execute("CREATE DATABASE sam_DB")
# my_cursor.execute("SHOW DATABASES")
# for i in my_cursor:
#     print(i)
# my_cursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")
# query= ("INSERT INTO customers (name, address) VALUES (%s, %s)")
# val = [('Peter', 'Lowstreet 4'),
#   ('Amy', 'Apple st 652'),
#   ('Hannah', 'Mountain 21'),
#   ('Michael', 'Valley 345'),
#   ('Sandy', 'Ocean blvd 2'),
#   ('Betty', 'Green Grass 1'),
#   ('Richard', 'Sky st 331'),
#   ('Susan', 'One way 98'),
#   ('Vicky', 'Yellow Garden 2'),
#   ('Ben', 'Park Lane 38'),
#   ('William', 'Central st 954'),
#   ('Chuck', 'Main Road 989'),
#   ('Viola', 'Sideway 1633')
# ]
# my_cursor.executemany(query, val)
# connect_db.commit()
# my_cursor.execute("SHOW TABLES")
# for i in my_cursor:
#     print(i)

my_cursor.execute("SELECT*FROM customers")
results= my_cursor.fetchall()

for i in results:
    print(i)
# Out:
# ('Sara', 'East Delhi')
# ('Peter', 'Lowstreet 4')
# ('Amy', 'Apple st 652')
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')
# ('Betty', 'Green Grass 1')
# ('Richard', 'Sky st 331')
# ('Susan', 'One way 98')
# ('Vicky', 'Yellow Garden 2')
# ('Ben', 'Park Lane 38')
# ('William', 'Central st 954')
# ('Chuck', 'Main Road 989')
# ('Viola', 'Sideway 1633')

# %%
# Craeting a pandas dataframe using sql query

df_customers= pd.read_sql_query("SELECT*FROM customers", connect_db)
df_customers
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        name          address
# 0      Sara       East Delhi
# 1     Peter      Lowstreet 4
# 2       Amy     Apple st 652
# 3    Hannah      Mountain 21
# 4   Michael       Valley 345
# 5     Sandy     Ocean blvd 2
# 6     Betty    Green Grass 1
# 7   Richard       Sky st 331
# 8     Susan       One way 98
# 9     Vicky  Yellow Garden 2
# 10      Ben     Park Lane 38
# 11  William   Central st 954
# 12    Chuck    Main Road 989
# 13    Viola     Sideway 1633

# %%
# Creating a dataframe using SQL Server

import pyodbc 

cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=LAB-STUDENT\SQLEXPRESS;"
                      "Database=sam_DB;"
                      "Trusted_Connection=yes;")


cursor = cnxn.cursor()

df_sql_ser= pd.read_sql("SELECT*FROM customers", cnxn)
df_sql_ser
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        name          address
# 0      John       Highway 21
# 1     Peter      Lowstreet 4
# 2       Amy     Apple st 652
# 3    Hannah      Mountain 21
# 4   Michael       Valley 345
# 5     Sandy     Ocean blvd 2
# 6     Betty    Green Grass 1
# 7   Richard       Sky st 331
# 8     Susan       One way 98
# 9     Vicky  Yellow Garden 2
# 10      Ben     Park Lane 38
# 11  William   Central st 954
# 12    Chuck    Main Road 989
# 13    Viola     Sideway 1633

# %%
# Creating a dataframe using SAS files

df_sas= pd.read_sas('airline.sas7bdat')
df_sas
# Out:
#       YEAR          Y      W       R      L      K
# 0   1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3   1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4   1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
#Converting back to csv and excel fies

# df_customers.to_csv('customers.csv')
df_customers.to_html('one.html')

# %%
df_html= pd.read_html('one.html')
# Out:
# [    Unnamed: 0     name          address
#  0            0     Sara       East Delhi
#  1            1    Peter      Lowstreet 4
#  2            2      Amy     Apple st 652
#  3            3   Hannah      Mountain 21
#  4            4  Michael       Valley 345
#  5            5    Sandy     Ocean blvd 2
#  6            6    Betty    Green Grass 1
#  7            7  Richard       Sky st 331
#  8            8    Susan       One way 98
#  9            9    Vicky  Yellow Garden 2
#  10          10      Ben     Park Lane 38
#  11          11  William   Central st 954
#  12          12    Chuck    Main Road 989
#  13          13    Viola     Sideway 1633]

# %%
import pandas as pd

airline= pd.read_sas("airline.sas7bdat")
airline
# Out:
#       YEAR          Y      W       R      L      K
# 0   1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3   1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4   1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
## Data Exploring
# Retrieving rows from a dataframe
# Top Rows
# Bottom Rows

# %%
# Top rows
#
airline.head()
# Out:
#      YEAR      Y      W       R      L      K
# 0  1948.0  1.214  0.243  0.1454  1.415  0.612
# 1  1949.0  1.354  0.260  0.2181  1.384  0.559
# 2  1950.0  1.569  0.278  0.3157  1.388  0.573
# 3  1951.0  1.948  0.297  0.3940  1.550  0.564
# 4  1952.0  2.265  0.310  0.3559  1.802  0.574

# %%
airline.head(n=15)
# Out:
#       YEAR      Y      W       R      L      K
# 0   1948.0  1.214  0.243  0.1454  1.415  0.612
# 1   1949.0  1.354  0.260  0.2181  1.384  0.559
# 2   1950.0  1.569  0.278  0.3157  1.388  0.573
# 3   1951.0  1.948  0.297  0.3940  1.550  0.564
# 4   1952.0  2.265  0.310  0.3559  1.802  0.574
# 5   1953.0  2.731  0.322  0.3593  1.926  0.711
# 6   1954.0  3.025  0.335  0.4025  1.964  0.776
# 7   1955.0  3.562  0.350  0.3961  2.116  0.827
# 8   1956.0  3.979  0.361  0.3822  2.435  0.800
# 9   1957.0  4.420  0.379  0.3045  2.707  0.921
# 10  1958.0  4.563  0.391  0.3284  2.706  1.067
# 11  1959.0  5.385  0.426  0.3856  2.846  1.083
# 12  1960.0  5.554  0.441  0.3193  3.089  1.481
# 13  1961.0  5.465  0.460  0.3079  3.122  1.736
# 14  1962.0  5.825  0.485  0.3783  3.184  1.926

# %%
airline.head(15)
# Out:
#       YEAR      Y      W       R      L      K
# 0   1948.0  1.214  0.243  0.1454  1.415  0.612
# 1   1949.0  1.354  0.260  0.2181  1.384  0.559
# 2   1950.0  1.569  0.278  0.3157  1.388  0.573
# 3   1951.0  1.948  0.297  0.3940  1.550  0.564
# 4   1952.0  2.265  0.310  0.3559  1.802  0.574
# 5   1953.0  2.731  0.322  0.3593  1.926  0.711
# 6   1954.0  3.025  0.335  0.4025  1.964  0.776
# 7   1955.0  3.562  0.350  0.3961  2.116  0.827
# 8   1956.0  3.979  0.361  0.3822  2.435  0.800
# 9   1957.0  4.420  0.379  0.3045  2.707  0.921
# 10  1958.0  4.563  0.391  0.3284  2.706  1.067
# 11  1959.0  5.385  0.426  0.3856  2.846  1.083
# 12  1960.0  5.554  0.441  0.3193  3.089  1.481
# 13  1961.0  5.465  0.460  0.3079  3.122  1.736
# 14  1962.0  5.825  0.485  0.3783  3.184  1.926

# %%
# Retrieve all rows except bottom 5 rows

airline.head(-5)
# Out:
#       YEAR          Y      W       R      L      K
# 0   1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3   1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4   1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
airline.shape
# Out:
# (32, 6)

# %%
# Retrieve all rows except top 5 rows

airline.tail(-5)
# Out:
#       YEAR          Y      W       R      L      K
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# 17  1965.0   9.120000  0.564  0.5879  3.623  2.257
# 18  1966.0  10.512000  0.586  0.5369  4.074  2.742
# 19  1967.0  13.020000  0.622  0.4443  4.710  3.564
# 20  1968.0  15.261000  0.666  0.3052  5.217  4.767
# 21  1969.0  16.313000  0.731  0.2332  5.569  6.511
# ...

# %%
# Retrieve 20 rows in random

airline.sample(10)
# Out:
#       YEAR          Y      W       R      L      K
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 26  1974.0  19.305000  1.131  0.2664  5.729  9.508
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 25  1973.0  17.014000  1.056  0.2668  5.662  8.557
# 31  1979.0  23.618999  1.779  0.5346  6.852  6.874
# 18  1966.0  10.512000  0.586  0.5369  4.074  2.742
# 19  1967.0  13.020000  0.622  0.4443  4.710  3.564
# 20  1968.0  15.261000  0.666  0.3052  5.217  4.767

# %%
# Retrieving information about the data frame

# Metadata (Data about the data)
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    32 non-null     float64
#  1   Y       32 non-null     float64
#  2   W       32 non-null     float64
#  3   R       32 non-null     float64
#  4   L       32 non-null     float64
#  5   K       32 non-null     float64
# dtypes: float64(6)
# memory usage: 1.6 KB

# %%
# Display the number of rows and columns

airline.shape
# Out:
# (32, 6)

# %%
# Display columns name and data

df= pd.read_csv(r"C:\Users\Administrator.LAB-STUDENT\CLASSES_Templates\DATA ANALYTICS\online_store_customer_data.csv")
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent'],
#       dtype='object')

# %%
list(df)
# Out:
# ['Transaction_date',
#  'Transaction_ID',
#  'Gender',
#  'Age',
#  'Marital_status',
#  'State_names',
#  'Segment',
#  'Employees_status',
#  'Payment_method',
#  'Referal',
#  'Amount_spent']

# %%
df[['Gender','Segment']].head()
# Out:
#    Gender   Segment
# 0  Female     Basic
# 1    Male     Basic
# 2    Male     Basic
# 3     NaN  Platinum
# 4    Male     Basic

# %%
# Retrieveing a Range of Rows

df[10:50]
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 10         1/4/2019          151210  Female  56.0        Married
# 11         1/5/2019          151211  Female  63.0        Married
# 12         1/5/2019          151212  Female  60.0        Married
# 13         1/5/2019          151213    Male  47.0         Single
# 14         1/5/2019          151214    Male  24.0        Married
# 15         1/6/2019          151215    Male  16.0         Single
# 16         1/6/2019          151216  Female  72.0        Married
# 17         1/7/2019          151217  Female  77.0        Married
# 18         1/7/2019          151218    Male  42.0        Married
# 19         1/8/2019          151219  Female  46.0        Married
# 20         1/8/2019          151220  Female  19.0        Married
# 21         1/8/2019          151221    Male  42.0        Married
# 22         1/8/2019          151222  Female  50.0        Married
# ...

# %%
# Delete Columns name

# Dropping 1 column

df5= df.drop(['Age','Marital_status','State_names'], axis=1)
df5.head()
# Out:
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
df.drop(['Referal','Payment_method'] ,axis=1, inplace=True)
df
# Out:
#        Age     State_names   Segment Employees_status  Amount_spent
# 0     19.0          Kansas     Basic     Unemployment       2051.36
# 1     49.0        Illinois     Basic    self-employed        544.04
# 2     63.0      New Mexico     Basic          workers       1572.60
# 3     18.0        Virginia  Platinum          workers       1199.79
# 4     27.0     Connecticut     Basic    self-employed           NaN
# ...    ...             ...       ...              ...           ...
# 2507  57.0  South Carolina  Platinum    self-employed        150.10
# 2508  36.0          Hawaii    Silver    self-employed        708.88
# 2509  22.0  South Carolina     Basic          workers       2030.07
# 2510  44.0        New York     Basic        Employees       1909.77
# 2511  48.0      California    Silver          workers       1073.15
#
# [2512 rows x 5 columns]

# %%
# Change Columns name

airline.rename(columns={"Y":"Year2022", "W":"Work"}, inplace=True)
airline
# Out:
#       YEAR   Year2022   Work       R      L      K
# 0   1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3   1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4   1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
airline.columns= ['Year2022','Y','W','Ro','Lo','Ko']
airline.head(3)
# Out:
#    Year2022      Y      W      Ro     Lo     Ko
# 0    1948.0  1.214  0.243  0.1454  1.415  0.612
# 1    1949.0  1.354  0.260  0.2181  1.384  0.559
# 2    1950.0  1.569  0.278  0.3157  1.388  0.573

# %%
df= pd.DataFrame({'$team':['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
                   '$points': [25, 12, 15, 14, 19, 23, 25, 29],
                   '$assists': [5, 7, 7, 9, 12, 9, 9, 4],
                   '$rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})

df
# Out:
#   $team  $points  $assists  $rebounds
# 0     A       25         5         11
# 1     A       12         7          8
# 2     A       15         7         10
# 3     A       14         9          6
# 4     B       19        12          6
# 5     B       23         9          5
# 6     B       25         9          9
# 7     B       29         4         12

# %%
df11= df.columns.str.replace("$","")
df11
# Out:
# C:\Users\Administrator.LAB-STUDENT\AppData\Local\Temp\ipykernel_8196\3379582538.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df11= df.columns.str.replace("$","")
# Index(['team', 'points', 'assists', 'rebounds'], dtype='object')

# %%
df1= pd.DataFrame({
    "Y2020":[1,2,3,5,6],
    "Y2021": [11,12,13,15,16]
})
df1
# Out:
#    Y2020  Y2021
# 0      1     11
# 1      2     12
# 2      3     13
# 3      5     15
# 4      6     16

# %%
df2= df1.columns.str.replace("Y","Year")
df2
# Out:
# Index(['Year2020', 'Year2021'], dtype='object')

# %%
"Y2020".replace("Y","Year")
# Out:
# 'Year2020'

# %%
# Change data type

df121= pd.read_csv(r"C:\Users\Administrator.LAB-STUDENT\CLASSES_Templates\DATA ANALYTICS\online_store_customer_data.csv")
# print(df.info())
print(df121.head())
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
# import matplotlib.pyplot as plt
df121['Gender']= df121['Gender'].astype("string")
df121['Amount_spent']= df121['Amount_spent'].astype(float) 
# df121.info()
# df121.dropna(subset=['Gender','Amount_spent'], inplace=True)
# df121.isnull().sum()
plt.bar(df121['Gender'],df121['Amount_spent'])
# Out:
# <BarContainer object of 2244 artists>

# %%
apples= [100,102,115,211]
days= ['East', "West","North","South"]
plt.bar(days, apples)
plt.xlabel("Region")
plt.ylabel("# of Apples Sold")
# Out:
# Text(0, 0.5, '# of Apples Sold')

# %%
airline
# Out:
#     Year2022          Y      W      Ro     Lo     Ko
# 0     1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1     1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2     1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3     1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4     1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5     1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6     1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7     1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8     1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9     1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10    1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11    1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12    1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13    1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14    1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15    1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16    1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
df= pd.DataFrame({'team':['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
                   'points': [25, 12, 15, 14, 19, 23, 25, 29],
                   'assists': [5, 7, 7, 9, 12, 9, 9, 4],
                   'rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})

df
# Out:
#   team  points  assists  rebounds
# 0    A      25        5        11
# 1    A      12        7         8
# 2    A      15        7        10
# 3    A      14        9         6
# 4    B      19       12         6
# 5    B      23        9         5
# 6    B      25        9         9
# 7    B      29        4        12

# %%
plt.bar(df['team'])
